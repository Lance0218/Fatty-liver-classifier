# %% [markdown]
# # Using matplotlib

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# create dataframes
df = pd.DataFrame({'features' : ['IB', 'HHT', 'HF', 'IB + HHT', 'IB + HF', 'HHT + HF', 'IB + HHT + HF'], 
                   'Sensitivity (%)' : [92.86, 67.86, 94.64, 83.93, 92.86, 87.50, 92.86],
                   'Specificity (%)' : [44.44, 72.22, 38.89, 77.78, 55.56, 50.00, 66.67],
                   'LR+' : [1.67, 2.44, 1.55, 3.78, 2.09, 1.75, 2.79],
                   'LR-' : [0.16, 0.45, 0.14, 0.21, 0.13, 0.25, 0.11],
                   'PPV (%)' : [83.87, 88.37, 82.81, 92.16, 86.67, 84.48, 89.66],
                   'NPV (%)' : [66.67, 41.94, 70.00, 60.87, 71.43, 56.25, 75.00],
                   'Accuracy (%)' : [81.08, 68.92, 81.08, 82.43, 83.78, 78.38, 86.49],
                   'AUROC' : [0.8651, 0.8006, 0.7927, 0.8839, 0.8819, 0.8442, 0.8929],})

# def Bar plot & save
def bar_plot(i):
    plt.figure(figsize = (20, 10))
    plt.bar(x, df[Parameters[i]], width = 0.7,color = 'lightblue', alpha = 0.8)
    plt.title('Feature Select VS. {0}'.format(Parameters[i]), size=30)
    plt.xlabel('Feature Select', size = 25)
    plt.ylabel('{0}'.format(Parameters[i]), size = 25)
    plt.xticks(x, df['features'], size = 15)
    plt.yticks(size = 15)
    plt.ylim(0, 1.4*max(df[Parameters[i]]))
    plt.savefig('Result Visualization\Feature Select VS. {0}.png'.format(Parameters[i]))
    plt.show()

# plot & save
x = np.arange(7)
Parameters = ['Sensitivity (%)', 'Specificity (%)', 'LR+', 'LR-', 'PPV (%)', 'NPV (%)', 'Accuracy (%)', 'AUROC']
for i in range(8):
    bar_plot(i)

# %% [markdown]
# # Using plotly but can't display on Github

# %%
import pandas as pd
import plotly.graph_objs as go
from plotly.offline import init_notebook_mode, iplot

# open offline plotly
init_notebook_mode(connected=True)

# create dataframes
df = pd.DataFrame({'features' : ['IB', 'HHT', 'HF', 'IB + HHT', 'IB + HF', 'HHT + HF', 'IB + HHT + HF'], 
                   'Sensitivity (%)' : [92.86, 67.86, 94.64, 83.93, 92.86, 87.50, 92.86],
                   'Specificity (%)' : [44.44, 72.22, 38.89, 77.78, 55.56, 50.00, 66.67],
                   'LR+' : [1.67, 2.44, 1.55, 3.78, 2.09, 1.75, 2.79],
                   'LR-' : [0.16, 0.45, 0.14, 0.21, 0.13, 0.25, 0.11],
                   'PPV (%)' : [83.87, 88.37, 82.81, 92.16, 86.67, 84.48, 89.66],
                   'NPV (%)' : [66.67, 41.94, 70.00, 60.87, 71.43, 56.25, 75.00],
                   'Accuracy (%)' : [81.08, 68.92, 81.08, 82.43, 83.78, 78.38, 86.49],
                   'AUROC' : [0.8651, 0.8006, 0.7927, 0.8839, 0.8819, 0.8442, 0.8929],})

# def Bar plot
def bar_plot(i):
    layout=go.Layout(title = 'Feature Select VS. {0}'.format(Parameters[i]),
                     titlefont = {'size':'30'},
                     xaxis = {'title':'Feature Select', 'titlefont':{'size':'20'}},
                     yaxis = {'title':'{0}'.format(Parameters[i]), 'titlefont':{'size':'20'}})
    data = [go.Bar(x = df['features'], y = df[Parameters[i]])]
    fig = go.Figure(data = data, layout = layout)
    iplot(fig)

#plot
Parameters = ['Sensitivity (%)', 'Specificity (%)', 'LR+', 'LR-', 'PPV (%)', 'NPV (%)', 'Accuracy (%)', 'AUROC']
for i in range(8):
    bar_plot(i)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# <div id="0e2c90f4-f380-442b-992b-f1c54a2d3c2e" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("0e2c90f4-f380-442b-992b-f1c54a2d3c2e", [{"type": "bar", "x": ["IB", "HHT", "HF", "IB + HHT", "IB + HF", "HHT + HF", "IB + HHT + HF"], "y": [92.86, 67.86, 94.64, 83.93, 92.86, 87.5, 92.86]}], {"title": "Feature Select VS. Sensitivity (%)", "titlefont": {"size": "30"}, "xaxis": {"title": "Feature Select", "titlefont": {"size": "20"}}, "yaxis": {"title": "Sensitivity (%)", "titlefont": {"size": "20"}}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>
# <div id="78f7f48d-d68d-455d-a4d1-51462521589f" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("78f7f48d-d68d-455d-a4d1-51462521589f", [{"type": "bar", "x": ["IB", "HHT", "HF", "IB + HHT", "IB + HF", "HHT + HF", "IB + HHT + HF"], "y": [44.44, 72.22, 38.89, 77.78, 55.56, 50.0, 66.67]}], {"title": "Feature Select VS. Specificity (%)", "titlefont": {"size": "30"}, "xaxis": {"title": "Feature Select", "titlefont": {"size": "20"}}, "yaxis": {"title": "Specificity (%)", "titlefont": {"size": "20"}}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>
# <div id="7e61b382-02d0-4f42-a84b-bd6957e8feaa" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("7e61b382-02d0-4f42-a84b-bd6957e8feaa", [{"type": "bar", "x": ["IB", "HHT", "HF", "IB + HHT", "IB + HF", "HHT + HF", "IB + HHT + HF"], "y": [1.67, 2.44, 1.55, 3.78, 2.09, 1.75, 2.79]}], {"title": "Feature Select VS. LR+", "titlefont": {"size": "30"}, "xaxis": {"title": "Feature Select", "titlefont": {"size": "20"}}, "yaxis": {"title": "LR+", "titlefont": {"size": "20"}}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>
# <div id="30e8887e-7765-42de-818a-7b549b167e84" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("30e8887e-7765-42de-818a-7b549b167e84", [{"type": "bar", "x": ["IB", "HHT", "HF", "IB + HHT", "IB + HF", "HHT + HF", "IB + HHT + HF"], "y": [0.16, 0.45, 0.14, 0.21, 0.13, 0.25, 0.11]}], {"title": "Feature Select VS. LR-", "titlefont": {"size": "30"}, "xaxis": {"title": "Feature Select", "titlefont": {"size": "20"}}, "yaxis": {"title": "LR-", "titlefont": {"size": "20"}}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>
# <div id="e2f58855-538a-4b2c-8a52-579202155f8f" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("e2f58855-538a-4b2c-8a52-579202155f8f", [{"type": "bar", "x": ["IB", "HHT", "HF", "IB + HHT", "IB + HF", "HHT + HF", "IB + HHT + HF"], "y": [83.87, 88.37, 82.81, 92.16, 86.67, 84.48, 89.66]}], {"title": "Feature Select VS. PPV (%)", "titlefont": {"size": "30"}, "xaxis": {"title": "Feature Select", "titlefont": {"size": "20"}}, "yaxis": {"title": "PPV (%)", "titlefont": {"size": "20"}}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>
# <div id="725598b0-b000-4a2d-9066-2e2db1850bd8" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("725598b0-b000-4a2d-9066-2e2db1850bd8", [{"type": "bar", "x": ["IB", "HHT", "HF", "IB + HHT", "IB + HF", "HHT + HF", "IB + HHT + HF"], "y": [66.67, 41.94, 70.0, 60.87, 71.43, 56.25, 75.0]}], {"title": "Feature Select VS. NPV (%)", "titlefont": {"size": "30"}, "xaxis": {"title": "Feature Select", "titlefont": {"size": "20"}}, "yaxis": {"title": "NPV (%)", "titlefont": {"size": "20"}}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>
# <div id="f864da49-8622-47bd-8270-0890b461838b" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("f864da49-8622-47bd-8270-0890b461838b", [{"type": "bar", "x": ["IB", "HHT", "HF", "IB + HHT", "IB + HF", "HHT + HF", "IB + HHT + HF"], "y": [81.08, 68.92, 81.08, 82.43, 83.78, 78.38, 86.49]}], {"title": "Feature Select VS. Accuracy (%)", "titlefont": {"size": "30"}, "xaxis": {"title": "Feature Select", "titlefont": {"size": "20"}}, "yaxis": {"title": "Accuracy (%)", "titlefont": {"size": "20"}}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>
# <div id="202b8cad-d65e-4361-ad89-fd16e398b095" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("202b8cad-d65e-4361-ad89-fd16e398b095", [{"type": "bar", "x": ["IB", "HHT", "HF", "IB + HHT", "IB + HF", "HHT + HF", "IB + HHT + HF"], "y": [0.8651, 0.8006, 0.7927, 0.8839, 0.8819, 0.8442, 0.8929]}], {"title": "Feature Select VS. AUROC", "titlefont": {"size": "30"}, "xaxis": {"title": "Feature Select", "titlefont": {"size": "20"}}, "yaxis": {"title": "AUROC", "titlefont": {"size": "20"}}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>
