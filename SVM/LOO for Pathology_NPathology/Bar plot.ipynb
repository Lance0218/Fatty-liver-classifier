# %% [markdown]
# # Using matplotlib

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# create dataframes
df = pd.DataFrame({'features' : ['IB', 'Q factor', 'HF', 'IB + Q factor', 'IB + HF', 'Q factor + HF', 'IB + Q factor + HF'], 
                   'Sensitivity (%)' : [92.86, 67.86, 94.64, 83.93, 92.86, 87.50, 92.86],
                   'Specificity (%)' : [44.44, 72.22, 38.89, 77.78, 55.56, 50.00, 66.67],
                   'LR+' : [1.67, 2.44, 1.55, 3.78, 2.09, 1.75, 2.79],
                   'LR-' : [0.16, 0.45, 0.14, 0.21, 0.13, 0.25, 0.11],
                   'PPV (%)' : [83.87, 88.37, 82.81, 92.16, 86.67, 84.48, 89.66],
                   'NPV (%)' : [66.67, 41.94, 70.00, 60.87, 71.43, 56.25, 75.00],
                   'Accuracy (%)' : [81.08, 68.92, 81.08, 82.43, 83.78, 78.38, 86.49],
                   'AUROC' : [0.8651, 0.8006, 0.7927, 0.8919, 0.8819, 0.8442, 0.8929],})

# def Bar plot & save
def bar_plot(i):
    plt.figure(figsize = (20, 10))
    plt.bar(X, df[Parameters[i]], width = 0.7,color = 'lightblue', alpha = 0.8)
    plt.title('Feature select VS. {0}'.format(Parameters[i]), size = 30)
    plt.xlabel('Feature select', size = 25)
    plt.ylabel('{0}'.format(Parameters[i]), size = 25)
    plt.xticks(X, df['features'], size = 15)
    plt.yticks(size = 15)
    plt.ylim(0, 1.4*max(df[Parameters[i]]))
    for x, y in zip(X, df[Parameters[i]]):
        plt.text(x, 1.05*y, y, ha = 'center', size = 15)
    plt.savefig('Result Visualization/Feature Select VS. {0}.png'.format(Parameters[i]))
    plt.show()

# plot & save
X = np.arange(7)
Parameters = ['Sensitivity (%)', 'Specificity (%)', 'LR+', 'LR-', 'PPV (%)', 'NPV (%)', 'Accuracy (%)', 'AUROC']
for i in range(8):
    bar_plot(i)

# %% [markdown]
# # Using plotly but can't display on Github

# %%
import pandas as pd
import plotly.graph_objs as go
from plotly.offline import init_notebook_mode, iplot

# open offline plotly
init_notebook_mode(connected=True)

# create dataframes
df = pd.DataFrame({'features' : ['IB', 'HHT', 'HF', 'IB + HHT', 'IB + HF', 'HHT + HF', 'IB + HHT + HF'], 
                   'Sensitivity (%)' : [92.86, 67.86, 94.64, 83.93, 92.86, 87.50, 92.86],
                   'Specificity (%)' : [44.44, 72.22, 38.89, 77.78, 55.56, 50.00, 66.67],
                   'LR+' : [1.67, 2.44, 1.55, 3.78, 2.09, 1.75, 2.79],
                   'LR-' : [0.16, 0.45, 0.14, 0.21, 0.13, 0.25, 0.11],
                   'PPV (%)' : [83.87, 88.37, 82.81, 92.16, 86.67, 84.48, 89.66],
                   'NPV (%)' : [66.67, 41.94, 70.00, 60.87, 71.43, 56.25, 75.00],
                   'Accuracy (%)' : [81.08, 68.92, 81.08, 82.43, 83.78, 78.38, 86.49],
                   'AUROC' : [0.8651, 0.8006, 0.7927, 0.8919, 0.8819, 0.8442, 0.8929],})

# def Bar plot
def bar_plot(i):
    layout=go.Layout(title = 'Feature select VS. {0}'.format(Parameters[i]),
                     titlefont = {'size':'30'},
                     xaxis = {'title':'Feature select', 'titlefont':{'size':'20'}},
                     yaxis = {'title':'{0}'.format(Parameters[i]), 'titlefont':{'size':'20'}})
    data = [go.Bar(x = df['features'], y = df[Parameters[i]])]
    fig = go.Figure(data = data, layout = layout)
    iplot(fig)

#plot
Parameters = ['Sensitivity (%)', 'Specificity (%)', 'LR+', 'LR-', 'PPV (%)', 'NPV (%)', 'Accuracy (%)', 'AUROC']
for i in range(8):
    bar_plot(i)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# <div id="6bc85c03-dcfc-40b0-8fa8-f748f90581c1" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("6bc85c03-dcfc-40b0-8fa8-f748f90581c1", [{"type": "bar", "x": ["IB", "HHT", "HF", "IB + HHT", "IB + HF", "HHT + HF", "IB + HHT + HF"], "y": [92.86, 67.86, 94.64, 83.93, 92.86, 87.5, 92.86]}], {"title": "Feature select VS. Sensitivity (%)", "titlefont": {"size": "30"}, "xaxis": {"title": "Feature select", "titlefont": {"size": "20"}}, "yaxis": {"title": "Sensitivity (%)", "titlefont": {"size": "20"}}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>
# <div id="210e8431-bb56-4509-a05e-cd911bfc5916" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("210e8431-bb56-4509-a05e-cd911bfc5916", [{"type": "bar", "x": ["IB", "HHT", "HF", "IB + HHT", "IB + HF", "HHT + HF", "IB + HHT + HF"], "y": [44.44, 72.22, 38.89, 77.78, 55.56, 50.0, 66.67]}], {"title": "Feature select VS. Specificity (%)", "titlefont": {"size": "30"}, "xaxis": {"title": "Feature select", "titlefont": {"size": "20"}}, "yaxis": {"title": "Specificity (%)", "titlefont": {"size": "20"}}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>
# <div id="865bb43d-06e3-4739-9710-b17bc4fe6aac" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("865bb43d-06e3-4739-9710-b17bc4fe6aac", [{"type": "bar", "x": ["IB", "HHT", "HF", "IB + HHT", "IB + HF", "HHT + HF", "IB + HHT + HF"], "y": [1.67, 2.44, 1.55, 3.78, 2.09, 1.75, 2.79]}], {"title": "Feature select VS. LR+", "titlefont": {"size": "30"}, "xaxis": {"title": "Feature select", "titlefont": {"size": "20"}}, "yaxis": {"title": "LR+", "titlefont": {"size": "20"}}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>
# <div id="c5802f85-5211-427a-b802-9aaeb118924d" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("c5802f85-5211-427a-b802-9aaeb118924d", [{"type": "bar", "x": ["IB", "HHT", "HF", "IB + HHT", "IB + HF", "HHT + HF", "IB + HHT + HF"], "y": [0.16, 0.45, 0.14, 0.21, 0.13, 0.25, 0.11]}], {"title": "Feature select VS. LR-", "titlefont": {"size": "30"}, "xaxis": {"title": "Feature select", "titlefont": {"size": "20"}}, "yaxis": {"title": "LR-", "titlefont": {"size": "20"}}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>
# <div id="19e77e24-0c69-4f9c-967d-8b87f7361cac" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("19e77e24-0c69-4f9c-967d-8b87f7361cac", [{"type": "bar", "x": ["IB", "HHT", "HF", "IB + HHT", "IB + HF", "HHT + HF", "IB + HHT + HF"], "y": [83.87, 88.37, 82.81, 92.16, 86.67, 84.48, 89.66]}], {"title": "Feature select VS. PPV (%)", "titlefont": {"size": "30"}, "xaxis": {"title": "Feature select", "titlefont": {"size": "20"}}, "yaxis": {"title": "PPV (%)", "titlefont": {"size": "20"}}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>
# <div id="9138f6a6-4e86-4421-80ed-c5a757bc045e" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("9138f6a6-4e86-4421-80ed-c5a757bc045e", [{"type": "bar", "x": ["IB", "HHT", "HF", "IB + HHT", "IB + HF", "HHT + HF", "IB + HHT + HF"], "y": [66.67, 41.94, 70.0, 60.87, 71.43, 56.25, 75.0]}], {"title": "Feature select VS. NPV (%)", "titlefont": {"size": "30"}, "xaxis": {"title": "Feature select", "titlefont": {"size": "20"}}, "yaxis": {"title": "NPV (%)", "titlefont": {"size": "20"}}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>
# <div id="443d9bdd-6633-484f-9056-66cc0bc65361" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("443d9bdd-6633-484f-9056-66cc0bc65361", [{"type": "bar", "x": ["IB", "HHT", "HF", "IB + HHT", "IB + HF", "HHT + HF", "IB + HHT + HF"], "y": [81.08, 68.92, 81.08, 82.43, 83.78, 78.38, 86.49]}], {"title": "Feature select VS. Accuracy (%)", "titlefont": {"size": "30"}, "xaxis": {"title": "Feature select", "titlefont": {"size": "20"}}, "yaxis": {"title": "Accuracy (%)", "titlefont": {"size": "20"}}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>
# <div id="e72cae4c-0d34-457b-aa86-8b850ddfe1c0" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("e72cae4c-0d34-457b-aa86-8b850ddfe1c0", [{"type": "bar", "x": ["IB", "HHT", "HF", "IB + HHT", "IB + HF", "HHT + HF", "IB + HHT + HF"], "y": [0.8651, 0.8006, 0.7927, 0.8919, 0.8819, 0.8442, 0.8929]}], {"title": "Feature select VS. AUROC", "titlefont": {"size": "30"}, "xaxis": {"title": "Feature select", "titlefont": {"size": "20"}}, "yaxis": {"title": "AUROC", "titlefont": {"size": "20"}}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>
