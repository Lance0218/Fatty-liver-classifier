# %% [markdown]
# # Using matplotlib

# %%
max(df[Parameters[1]])
# Out:
# 77.780000000000001

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# create dataframes
df = pd.DataFrame({'features' : ['IB', 'HHT', 'HF', 'IB + HHT', 'IB + HF', 'HHT + HF', 'IB + HHT + HF'], 
                   'Sensitivity (%)' : [92.86, 67.86, 94.64, 83.93, 92.86, 87.50, 92.86],
                   'Specificity (%)' : [44.44, 72.22, 38.89, 77.78, 55.56, 50.00, 66.67],
                   'LR+' : [1.67, 2.44, 1.55, 3.78, 2.09, 1.75, 2.79],
                   'LR-' : [0.16, 0.45, 0.14, 0.21, 0.13, 0.25, 0.11],
                   'PPV (%)' : [83.87, 88.37, 82.81, 92.16, 86.67, 84.48, 89.66],
                   'NPV (%)' : [66.67, 41.94, 70.00, 60.87, 71.43, 56.25, 75.00],
                   'Accuracy (%)' : [81.08, 68.92, 81.08, 82.43, 83.78, 78.38, 86.49],
                   'AUROC' : [0.8651, 0.8006, 0.7927, 0.8839, 0.8819, 0.8442, 0.8929],})

# def Bar plot & save
def bar_plot(i):
    plt.figure(figsize = (20, 10))
    plt.bar(x, df[Parameters[i]], width = 0.7,color = 'lightblue', alpha = 0.8)
    plt.title('{0} Compare of Feature Select'.format(Parameters[i]), size=30)
    plt.xlabel('Feature Select', size = 25)
    plt.ylabel('{0}'.format(Parameters[i]), size = 25)
    plt.xticks(x, df['features'], size = 15)
    plt.yticks(size = 15)
    plt.ylim(0, 1.4*max(df[Parameters[i]]))
    plt.savefig('figure\{0} Compare of Feature Select.png'.format(Parameters[i]))
    plt.show()

# plot & save
x = np.arange(7)
Parameters = ['Sensitivity (%)', 'Specificity (%)', 'LR+', 'LR-', 'PPV (%)', 'NPV (%)', 'Accuracy (%)', 'AUROC']
for i in range(8):
    bar_plot(i)

# %% [markdown]
# # Using plotly but can't display on Github

# %%
import pandas as pd
import plotly.graph_objs as go
from plotly.offline import init_notebook_mode, iplot

# open offline plotly
init_notebook_mode(connected=True)

# create dataframes
df = pd.DataFrame({'features' : ['IB', 'HHT', 'HF', 'IB + HHT', 'IB + HF', 'HHT + HF', 'IB + HHT + HF'], 
                   'Sensitivity (%)' : [92.86, 67.86, 94.64, 83.93, 92.86, 87.50, 92.86],
                   'Specificity (%)' : [44.44, 72.22, 38.89, 77.78, 55.56, 50.00, 66.67],
                   'LR+' : [1.67, 2.44, 1.55, 3.78, 2.09, 1.75, 2.79],
                   'LR-' : [0.16, 0.45, 0.14, 0.21, 0.13, 0.25, 0.11],
                   'PPV (%)' : [83.87, 88.37, 82.81, 92.16, 86.67, 84.48, 89.66],
                   'NPV (%)' : [66.67, 41.94, 70.00, 60.87, 71.43, 56.25, 75.00],
                   'Accuracy (%)' : [81.08, 68.92, 81.08, 82.43, 83.78, 78.38, 86.49],
                   'AUROC' : [0.8651, 0.8006, 0.7927, 0.8839, 0.8819, 0.8442, 0.8929],})

# def Bar plot
def bar_plot(i):
    layout=go.Layout(title = '{0} Compare of Feature Select'.format(Parameters[i]),
                     titlefont = {'size':'30'},
                     xaxis = {'title':'Feature Select', 'titlefont':{'size':'20'}},
                     yaxis = {'title':'{0}'.format(Parameters[i]), 'titlefont':{'size':'20'}})
    data = [go.Bar(x = df['features'], y = df[Parameters[i]])]
    fig = go.Figure(data = data, layout = layout)
    iplot(fig)

#plot
Parameters = ['Sensitivity (%)', 'Specificity (%)', 'LR+', 'LR-', 'PPV (%)', 'NPV (%)', 'Accuracy (%)', 'AUROC']
for i in range(8):
    bar_plot(i)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# <div id="fbf71015-f49e-48c7-979c-624ec68a4b0e" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("fbf71015-f49e-48c7-979c-624ec68a4b0e", [{"type": "bar", "x": ["IB", "HHT", "HF", "IB + HHT", "IB + HF", "HHT + HF", "IB + HHT + HF"], "y": [92.86, 67.86, 94.64, 83.93, 92.86, 87.5, 92.86]}], {"title": "Sensitivity (%) Compare of Feature Select", "titlefont": {"size": "30"}, "xaxis": {"title": "Feature Select", "titlefont": {"size": "20"}}, "yaxis": {"title": "Sensitivity (%)", "titlefont": {"size": "20"}}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>
# <div id="8c6b22b8-6619-4009-8777-0b6d4c897557" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("8c6b22b8-6619-4009-8777-0b6d4c897557", [{"type": "bar", "x": ["IB", "HHT", "HF", "IB + HHT", "IB + HF", "HHT + HF", "IB + HHT + HF"], "y": [44.44, 72.22, 38.89, 77.78, 55.56, 50.0, 66.67]}], {"title": "Specificity (%) Compare of Feature Select", "titlefont": {"size": "30"}, "xaxis": {"title": "Feature Select", "titlefont": {"size": "20"}}, "yaxis": {"title": "Specificity (%)", "titlefont": {"size": "20"}}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>
# <div id="a36c2dba-d14e-4392-af1f-b17c92c2a13b" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("a36c2dba-d14e-4392-af1f-b17c92c2a13b", [{"type": "bar", "x": ["IB", "HHT", "HF", "IB + HHT", "IB + HF", "HHT + HF", "IB + HHT + HF"], "y": [1.67, 2.44, 1.55, 3.78, 2.09, 1.75, 2.79]}], {"title": "LR+ Compare of Feature Select", "titlefont": {"size": "30"}, "xaxis": {"title": "Feature Select", "titlefont": {"size": "20"}}, "yaxis": {"title": "LR+", "titlefont": {"size": "20"}}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>
# <div id="be4a50fc-9f76-4222-906a-ea9cc363dc0a" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("be4a50fc-9f76-4222-906a-ea9cc363dc0a", [{"type": "bar", "x": ["IB", "HHT", "HF", "IB + HHT", "IB + HF", "HHT + HF", "IB + HHT + HF"], "y": [0.16, 0.45, 0.14, 0.21, 0.13, 0.25, 0.11]}], {"title": "LR- Compare of Feature Select", "titlefont": {"size": "30"}, "xaxis": {"title": "Feature Select", "titlefont": {"size": "20"}}, "yaxis": {"title": "LR-", "titlefont": {"size": "20"}}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>
# <div id="f074716a-60fe-4c00-9159-dce49b786e51" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("f074716a-60fe-4c00-9159-dce49b786e51", [{"type": "bar", "x": ["IB", "HHT", "HF", "IB + HHT", "IB + HF", "HHT + HF", "IB + HHT + HF"], "y": [83.87, 88.37, 82.81, 92.16, 86.67, 84.48, 89.66]}], {"title": "PPV (%) Compare of Feature Select", "titlefont": {"size": "30"}, "xaxis": {"title": "Feature Select", "titlefont": {"size": "20"}}, "yaxis": {"title": "PPV (%)", "titlefont": {"size": "20"}}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>
# <div id="ffe03ec3-611b-444b-9bdc-9d7243017f6b" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("ffe03ec3-611b-444b-9bdc-9d7243017f6b", [{"type": "bar", "x": ["IB", "HHT", "HF", "IB + HHT", "IB + HF", "HHT + HF", "IB + HHT + HF"], "y": [66.67, 41.94, 70.0, 60.87, 71.43, 56.25, 75.0]}], {"title": "NPV (%) Compare of Feature Select", "titlefont": {"size": "30"}, "xaxis": {"title": "Feature Select", "titlefont": {"size": "20"}}, "yaxis": {"title": "NPV (%)", "titlefont": {"size": "20"}}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>
# <div id="6510c291-9dc2-4b8f-a680-288f73fd3df9" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("6510c291-9dc2-4b8f-a680-288f73fd3df9", [{"type": "bar", "x": ["IB", "HHT", "HF", "IB + HHT", "IB + HF", "HHT + HF", "IB + HHT + HF"], "y": [81.08, 68.92, 81.08, 82.43, 83.78, 78.38, 86.49]}], {"title": "Accuracy (%) Compare of Feature Select", "titlefont": {"size": "30"}, "xaxis": {"title": "Feature Select", "titlefont": {"size": "20"}}, "yaxis": {"title": "Accuracy (%)", "titlefont": {"size": "20"}}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>
# <div id="a2f8fef4-a5d3-4cf4-8a5e-478393019d1a" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("a2f8fef4-a5d3-4cf4-8a5e-478393019d1a", [{"type": "bar", "x": ["IB", "HHT", "HF", "IB + HHT", "IB + HF", "HHT + HF", "IB + HHT + HF"], "y": [0.8651, 0.8006, 0.7927, 0.8839, 0.8819, 0.8442, 0.8929]}], {"title": "AUROC Compare of Feature Select", "titlefont": {"size": "30"}, "xaxis": {"title": "Feature Select", "titlefont": {"size": "20"}}, "yaxis": {"title": "AUROC", "titlefont": {"size": "20"}}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>
